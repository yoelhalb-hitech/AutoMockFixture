# %% [markdown]
# # AutoMockFixture: A Comprehensive Overview
#
# AutoMockFixture is a powerful library that combines AutoFixture and Moq to simplify unit testing. It provides automatic creation of test objects and mocks, customizable object creation, and more.
#
# This notebook provides an introduction to the AutoMockFixture ecosystem, explaining its purpose, key components, and basic usage.
#
# ## Purpose of AutoMockFixture:
# 1. Automate creation of test objects and mocks
# 2. Provide flexible customization of object creation and mocking
# 3. Offer a unified approach for unit and integration testing
# 4. Enhance test readability through attribute-based testing
#
# ## Key Components of AutoMockFixture:
# 1. UnitFixture: For unit testing, mocks dependencies by default
# 2. IntegrationFixture: For integration testing, uses real instances where possible
# 3. AutoMock: A customized Moq derivative with enhanced capabilities
# 4. Attribute-based testing: UnitAutoData and IntegrationAutoData attributes
# 5. Path system: For complex method setup and object retrieval

# %% [markdown]
# First, let's import the necessary packages and namespaces:

# %%
#r "nuget: AutoMockFixture.Moq4"
using AutoMockFixture.Moq4;
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>AutoMockFixture.Moq4, 8.0.0</span></li></ul></div></div>

# %% [markdown]
# ## Basic Usage
#
# Let's start by creating a UnitFixture, which is designed for unit testing scenarios.
#
# The main differences between UnitFixture and IntegrationFixture are:
# 1. By default, IntegrationFixture doesn't automatically mock non-interface and non-abstract dependencies.
#    However, this behavior can be overridden using SubclassCustomization, UseServices, or AutoMockTypeControl.
# 2. For class dependencies (both abstract and non-abstract), IntegrationFixture sets CallBase to true by default.
#    UnitFixture sets CallBase to false for abstract class dependencies and doesn't mock non-abstract classes by default.
#
# Note: The mocking behavior can be customized for both fixtures using AutoMockTypeControl.

# %% [markdown]
# Let's create a UnitFixture:

# %%
var fixture = new UnitFixture();

// Note: For integration testing, use:
// using var fixture = new IntegrationFixture();

// Note: In a normal C# environment, you'd use a 'using' statement:
// using var fixture = new UnitFixture();
// However, the notebook environment doesn't support this syntax.

# %% [markdown]
# Now, let's create a simple object:

# %%
public record SimpleObject
{
    public string Name { get; set; }
    public int Value { get; set; }
}

var simpleObject = fixture.Create<SimpleObject>();
simpleObject
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>SimpleObject { Name = Namee7951228-1667-43d1-b968-c0927cfa584c, Value = 64 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Namee7951228-1667-43d1-b968-c0927cfa584c</pre></div></td></tr><tr><td>Value</td><td><div class="dni-plaintext"><pre>64</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# Next, let's request an interface, which will automatically end up with a mock:

# %%
public interface IExampleService
{
    void DoSomething();
}

var mockService = fixture.Create<IExampleService>();
mockService
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Mock&lt;Submission#5.IExampleService:1&gt;.Object</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Mock</td><td><div class="dni-plaintext"><pre>Mock&lt;Submission#5.IExampleService:1&gt;.Object</pre></div></td></tr><tr><td>Mock</td><td><div class="dni-plaintext"><pre>Mock&lt;Submission#5.IExampleService:1&gt;.Object</pre></div></td></tr><tr><td>Interceptor</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Mock&lt;Submission#5.IExampleService:1&gt;</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Object</td><td><div class="dni-plaintext"><pre>Mock&lt;Submission#5.IExampleService:1&gt;</pre></div></td></tr><tr><td>Tracker</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>AutoMockFixture.FixtureUtils.Requests.MainRequests.AutoMockDirectRequest</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Request</td><td>AutoMockFixture.Moq4.AutoMock&lt;Submission#5+IExampleService&gt;</td></tr><tr><td>InstancePath</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>MockDependencies</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Fixture</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ [ [ [ [ [ [ AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, [ AutoFixture.Kernel.FixedBuilder ], AutoFixture.Kernel.StableFiniteSequenceRelay, [ [ AutoFixture.Kernel.MethodInvoker ] ], [ [ AutoFixture.Kernel.MethodInvoker ] ], [ [ AutoFixture.Kernel.MethodInvoker ] ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ] ... (more) ] ], [ [ [ [ AutoFixture.StringGenerator, AutoFixture.ConstrainedStringGenerator, AutoFixture.StringSeedRelay, AutoFixture.RandomNumericSequenceGenerator, AutoFixture.RandomCharSequenceGenerator, AutoFixture.UriGenerator, AutoFixture.UriSchemeGenerator, AutoFixture.RandomRangedNumberGenerator, AutoFixture.RegularExpressionGenerator, AutoFixture.RandomDateTimeSequenceGenerator, AutoFixture.BooleanSwitch, AutoFixture.GuidGenerator, AutoFixture.TypeGenerator, AutoFixture.Kernel.DelegateGenerator, AutoFixture.TaskGenerator, AutoFixture.Kernel.IntPtrGuard, AutoFixture.MailAddressGenerator, AutoFixture.EmailAddressLocalPartGenerator, AutoFixture.DomainNameGenerator, AutoFixture.LazyRelay ... (more) ], AutoFixture.Kernel.MultipleRelay ] ] ], [ [ AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.EnumerableRelay, AutoFixture.Kernel.EnumeratorRelay, AutoMockFixture.FixtureUtils.Builders.MainBuilders.AutoMockRelay ] ], [ AutoFixture.Kernel.MutableValueTypeWarningThrower ] ] ] ] ] ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>AutoMoc ...

# %% [markdown]
# Finally, let's create an object with dependencies:

# %%
public record WithDependecies(IExampleService Service);

var withDependecies = fixture.Create<WithDependecies>();
withDependecies
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>WithDependecies { Service = Mock&lt;Submission#5.IExampleService:2&gt;.Object }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Service</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Mock&lt;Submission#5.IExampleService:2&gt;.Object</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Mock</td><td><div class="dni-plaintext"><pre>Mock&lt;Submission#5.IExampleService:2&gt;.Object</pre></div></td></tr><tr><td>Mock</td><td><div class="dni-plaintext"><pre>Mock&lt;Submission#5.IExampleService:2&gt;.Object</pre></div></td></tr><tr><td>Interceptor</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Mock&lt;Submission#5.IExampleService:2&gt;</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Object</td><td><div class="dni-plaintext"><pre>Mock&lt;Submission#5.IExampleService:2&gt;</pre></div></td></tr><tr><td>Tracker</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>AutoMockFixture.FixtureUtils.Requests.MainRequests.AutoMockDirectRequest</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Request</td><td>AutoMockFixture.Moq4.AutoMock&lt;Submission#5+IExampleService&gt;</td></tr><tr><td>InstancePath</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>MockDependencies</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Fixture</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ [ [ [ [ [ [ AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, AutoMockFixture.FixtureUtils.Customizations.SubclassTransformCustomization+SubClassTransformBuilder, [ AutoFixture.Kernel.FixedBuilder ], AutoFixture.Kernel.StableFiniteSequenceRelay, [ [ AutoFixture.Kernel.MethodInvoker ] ], [ [ AutoFixture.Kernel.MethodInvoker ] ], [ [ AutoFixture.Kernel.MethodInvoker ] ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ], [ AutoFixture.Kernel.MethodInvoker ] ... (more) ] ], [ [ [ [ AutoFixture.StringGenerator, AutoFixture.ConstrainedStringGenerator, AutoFixture.StringSeedRelay, AutoFixture.RandomNumericSequenceGenerator, AutoFixture.RandomCharSequenceGenerator, AutoFixture.UriGenerator, AutoFixture.UriSchemeGenerator, AutoFixture.RandomRangedNumberGenerator, AutoFixture.RegularExpressionGenerator, AutoFixture.RandomDateTimeSequenceGenerator, AutoFixture.BooleanSwitch, AutoFixture.GuidGenerator, AutoFixture.TypeGenerator, AutoFixture.Kernel.DelegateGenerator, AutoFixture.TaskGenerator, AutoFixture.Kernel.IntPtrGuard, AutoFixture.MailAddressGenerator, AutoFixture.EmailAddressLocalPartGenerator, AutoFixture.DomainNameGenerator, AutoFixture.LazyRelay ... (more) ], AutoFixture.Kernel.MultipleRelay ] ] ], [ [ AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.TypeRelay, AutoFixture.Kernel.EnumerableRelay, AutoFixt ...
